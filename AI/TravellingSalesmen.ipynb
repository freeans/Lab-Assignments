# %%
from sys import maxsize
from itertools import permutations
v=4
def tsp(graph,s):
    vertex=[]
    for i in range(v):
        if i!=s:
            vertex.append(i)


    min_path=maxsize
    next_permutation=permutations(vertex)

    for i in next_permutation:
        current_path_weight=0
        k=s
        for j in i:
            current_path_weight+=graph[k][j]
            k=j

        current_path_weight+=[k][s]

        min_path=min(min_path,current_path_weight)

    return min_path



if __name__ =="__main__":
    graph=[[0,10,20,30],
          [10,0,35,25],
          [20,35,0,45],
          [30,25,45,0]]
    s=0;
    print(tsp(graph,s))
# Out:
# 82

# %%
from sys import maxsize
from itertools import permutations
v=4
def tsp(graph,s):
    vertex=[]
    for i in range(v):
        if i!=s:
            vertex.append(i)

    min_path=maxsize
    next_permutation=permutations(vertex)

    for i in next_permutation:
        current_path_weigth=0
        k=s
        for j in i:
            current_path_weigth+=graph[k][j]
            k=j
        current_path_weigth+=graph[k][s]
        min_path=min(min_path,current_path_weigth)
    return min_path

if __name__ =="__main__":
    graph=[[0,10,20,30],
          [10,0,25,35],
          [20,25,0,40],
          [30,35,45,0]]
    s=0
    print(tsp(graph,s))
# Out:
# 105

# %%
from sys import maxsize
from itertools import permutations
v=4

def tsp(graph,s):
    vertex=[]
    for i in range(v):
        if i!=s:
            vertex.append(i)
    min_path=maxsize
    next_permutation=permutations(vertex)

    for i in next_permutation:
        current_path_weight=0
        k=s
        for j in i:
            current_path_weight+=graph[k][j]
            k=j
        current_path_weight+=graph[k][s]
        min_path=min(min_path,current_path_weight)

    return min_path

if __name__=="__main__":
    graph=[[0,10,20,30],
          [10,0,25,35],
          [20,25,0,40],
          [30,35,40,0]]
    s=0
    print(tsp(graph,s))
# Out:
# 105

# %%
from sys import maxsize
from itertools import permutations

v=4

def tsp(graph,s):
    vertex=[]
    for i in range(v):
        if i!=s:
            vertex.append(i)

    min_path=maxsize
    next_permutation=permutations(vertex)
    for i in next_permutation:
        current_path_weight=0
        k=s
        for j in i:
            current_path_weight+=graph[k][j]
            k=j
        current_path_weight+=graph[k][s]
        min_path(min_path,current_path_weight)

    return min_path

if __name__ == "__main__":
    graph=[[0,10,20,30],
          [10,0,25,35],
          [20,25,0,40],
          [30,35,40,0]]
    s=0
    print(tsp(graph,s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 31
#      26 graph=[[0,10,20,30],
#      27       [10,0,25,35],
#      28       [20,25,0,40],
#      29       [30,35,40,0]]
#      30 s=0
# ---> 31 print(tsp(graph,s))
#
# Cell In[20], line 21, in tsp(graph, s)
#      19         k=j
#      20     current_path_weight+=graph[k][s]
# ---> 21     min_path(min_path,current_path_weight)
#      23 return min_path
#
# TypeError: 'int' object is not callable
